# %% [markdown]
# # heading1

# %% [markdown]
# ## heading2

# %% [markdown]
# ### heading3

# %% [markdown]
# #### heading4

# %% [markdown]
# ##### heading5

# %% [markdown]
# ###### heading6

# %% [markdown]
# # hiiii

# %% [markdown]
# **Data Science**

# %% [markdown]
# # *hiiii*

# %% [markdown]
# ## *Data science*

# %% [markdown]
# - monika
# - dharunya
# - sreya

# %% [markdown]
# 1. monika
# 2. dharunya
# 3. sreya

# %% [markdown]
# * monika
# * dharunya
# * sreya

# %% [markdown]
# print("hii")

# %% [markdown]
# ''' print("hii")'''

# %% [markdown]
# - - -

# %% [markdown]
# | name| mark| Course|
# |-----|-----|-------|
# | MONI | 65 | CSDA |
# | RAM | 89 | CSDA |

# %%
# %time sum(range(100))
# Out:
# CPU times: total: 0 ns
# Wall time: 51.5 μs
# 4950

# %%
# %%time
total = 0
for i in range(1000):
    total+=1
# Out:
# CPU times: total: 0 ns
# Wall time: 115 μs

# %%
# %pwd
# %history
# Out:
# ### heading3
# ### heading3
# ### heading3
# print("hii")
# ---
# %time sum(range(100))
# %%time
# total = 0
# for i in range(1000):
#     total+=1
# %%time
# total = 0
# for i in range(1000):
#     total+=1;
# %%time
# total = 0
# for i in range(1000):
#     total+=1
# %pwd
# %pwd
# %history

# %%
# %who
# Out:
# i	 total

# %%
# %ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 1E91-3043
#
#  Directory of C:\Users\monik\Downloads\Jupiter workbook
#
# 29-05-2026  15:42    <DIR>          .
# 29-05-2026  14:51    <DIR>          ..
# 29-05-2026  14:51    <DIR>          .ipynb_checkpoints
# 29-05-2026  15:42             5,265 Untitled.ipynb
#                1 File(s)          5,265 bytes
#                3 Dir(s)  117,001,220,096 bytes free

# %%
# %%writefile sample.py
print("Hi")
# Out:
# Overwriting sample.py

# %%
# %run sample.py
# Out:
# Hi
